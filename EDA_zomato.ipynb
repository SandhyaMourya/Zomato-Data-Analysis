# %%
## Import Libraries 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Load data set to dataframe using read_csv 
df=pd.read_csv("zomato.csv",encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
## Display all the columns exist in dataframe read from zomato.csv file
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
## Get an overview of the dataset like no of columns, datatype of each column also number of non null count from each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
## Learn about each dataset using disriptive analystics such as mean, std, min , max and count. 
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Alternate way to check columns having null values
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# ['Cuisines']

# %%
#Heat MAP
sns.heatmap(df.isnull(),yticklabels=False, cbar=False,cmap='viridis')

# %%
df_country=pd.read_excel('Country-Code.xlsx')

# %%
df_country.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
## Here we find the country of each country from COuntry-Code.xlsx file.
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
## Merge both tables 
final_df=pd.merge(df,df_country,on='Country Code',how='left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
## Finding the count of each countires 
final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
Country_names=final_df.Country.value_counts().index
Country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
Country_values=final_df.Country.value_counts().values
Country_values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4])

# %%
##PIE CHART
##Top countries where Zomato is

plt.pie(Country_values[:3],labels=Country_names[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f74ca69ce10>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# Observation:
# Number of transactions is maximum in India  amoung all the countries.

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df_rating=final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
df_rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
##Observations: 
##Maximum number of ratings are around between 2.9 to 3.9 as per the below bar plot. 

## Below are rating provided for below rating ranges.
# ratings from 1.8 to 2.4 = Poor
# ratings from 2.5 to 3.4 = Average
# ratings from 3.5 to 3.9 = Good
# ratings from 4.0 to 4.5 = Very Good
# ratings from 4.6 to 4.9 = Excellent

## Maximun number of people have not rated yet i.e around 2148 


import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)

sns.barplot(x='Aggregate rating',y='Rating Count',data=df_rating)

# %%
## Changing the palette as per the Rating color column. 
sns.barplot(x='Aggregate rating',y='Rating Count',data=df_rating,hue='Rating color',palette=['white','red','orange','yellow','green','green'])

# %%
##Observation

#1.Not rated count is very high i.e rating =0 which is indiated using white color.

# %%
#Count plot for catogarical Rating color 
sns.countplot(x='Rating color',data=df_rating,hue='Rating color',palette=['white','red','orange','yellow','green','green'])

# %%
## Query to find countries with counts par each rating
df_country_rating=final_df.groupby(['Aggregate rating','Country']).size().reset_index().rename(columns={0:'Rating Count per country'})
df_country_rating
# Out:
#      Aggregate rating         Country  Rating Count per country
# 0                 0.0          Brazil                         5
# 1                 0.0           India                      2139
# 2                 0.0  United Kingdom                         1
# 3                 0.0   United States                         3
# 4                 1.8           India                         1
# ..                ...             ...                       ...
# 217               4.9       Sri Lanka                         1
# 218               4.9          Turkey                         3
# 219               4.9             UAE                         4
# 220               4.9  United Kingdom                         4
# 221               4.9   United States                        14
#
# [222 rows x 3 columns]

# %%
## Find countries with zero rating
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index
# Out:
# <bound method Series.reset_index of Country
# Brazil               5
# India             2139
# United Kingdom       1
# United States        3
# dtype: int64>

# %% [markdown]
# Observation:
# Maximun number ratings is from Inda
#
# *   List item
# *   List item

# %%
## FInd out which currency is used by which country
df_currency=final_df.groupby(['Currency','Country']).size().reset_index().rename(columns={0:'Number of currency'})
df_currency
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-020ff88d92ed> in <module>
#       1 ## FInd out which currency is used by which country
# ----> 2 df_currency=final_df.groupby(['Currency','Country']).size().reset_index().rename(columns={0:'Number of currency'})
#       3 df_currency
#
# NameError: name 'final_df' is not defined

# %%
##Which countries do have online deliverable options
final_df[final_df['Has Online delivery']=='Yes'].groupby(['Country','Has Online delivery']).size().reset_index().rename(columns={0:'Count'})

# %%
##oBservation
#Both India and UAE has online delvery option

# %%
## Create a Pie char for top city distribution
city_values=final_df['City'].value_counts()
city_labels=final_df['City'].value_counts().index
plt.pie(city_values[:5],labels=city_labels[:5],autopct="%1.2f%%")

# %%
##Observation
##Maximun number of orders are from Newdelhi amoung all cites

# %% [markdown]
# **`Observation`**
#
# 1.Maximun number of orders are from Newdelhi amoung all the cites
#
# 2.Both India and UAE has online delvery option
#
# 3.Maximun number ratings is from Inda amoung all other counties.
#
# 4.Not rated count ie. rating =0  is very high amoung all other rating counts.
#
# 5.Maximum number of ratings are around between 2.9 to 3.9 as per the below bar plot.
#
# 6.Number of transactions/customers is maximum in India  amoung all the countries.
#
# 7.Cuisines column has 9 missing values in the dataset
#
# 8.Below are rating provided for below rating ranges.
#
# *   ratings from 1.8 to 2.4 = Poor
# *   ratings from 2.5 to 3.4 = Average
# *   ratings from 3.5 to 3.9 = Good
# *   ratings from 4.0 to 4.5 = Very Good
# *   ratings from 4.6 to 4.9 = Excellent
#
# 9.Maximun number of people have not rated yet i.e around 2148
